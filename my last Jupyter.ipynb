# %% [markdown]
#  # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Maram Ali Al Hinai
# Data entry

# %% [markdown]
# I am interested in data science because I am intersted in science in general and data science is how we obtain scientific quantities.

# %% [markdown]
# ### Make sure that 2+2 is 4

# %%
if (2+2) == 4 :
  print("good")
# Out:
# good

# %% [markdown]
# <br>
# <span style='font-size:100px;'>&#9672;</span>
#
# ```python
# Heheheeee
# ```
